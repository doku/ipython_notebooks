# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math

# %% [raw]
# Generate some data

# %%
how_many_clusters = 5
scale = .2
size_per_cluster = 50

k = 0
for i in range(how_many_clusters):
    k = np.append(k, np.random.normal(i+1,scale,size_per_cluster))
k = sorted(k)
plt.scatter(k,[0 for i in k])
plt.show()

# %% [raw]
# Clustering algorithm based on k-means algorithm

# %%
meanofmean = []
times_random_start = 50
times_iterate_to_local_min = 50
how_many_clusters = 5

for l in range(times_random_start):
    g = how_many_clusters
    bins = []
    means = []
    for i in range(g):
        bins.append([])
        means.append(random.random()*g)
    means = sorted(means)
    
    for p in range(times_iterate_to_local_min):
        for i, j in enumerate(k):
            least = j
            leastdiff = 0
            for m, n in enumerate(means):
                if m == 0:
                    least = m
                    leastdiff = math.fabs(n-j)
                elif math.fabs(n-j) < leastdiff:
                    least = m
                    leastdiff = math.fabs(n-j)
            else:
                bins[least].append(j)
                
        #print bins
        means = [sum(i)/len(i) if len(i) != 0 else 0 for i in bins]
    print means
    
    sumdiff = 0
    for u in range(1,len(means)):
        sumdiff += means[u] - means[u-1]
    else:
        meanofmean.append(sumdiff / (len(means)-1))
print meanofmean
print sum(meanofmean)/(len(meanofmean))
# Out:
# [0.0, 1.0369694678922046, 2.4521280208467666, 3.8375898515862694, 4.9764967772466155]
# [0.71771537953285214, 1.0869409337902192, 2.0181998149236198, 3.2174761662448628, 4.6354827582695624]
# [0.97294286786169504, 2.0003089420621536, 2.9918773813570625, 3.9311919793135695, 4.971354932907154]
# [0.83883680979798092, 1.3348728203760258, 2.5121293525317432, 3.862861472649882, 4.9777047738389202]
# [0.9519556190830708, 1.6870167493178048, 2.0686715462073244, 3.1257307141471595, 4.538406632711121]
# [0.97841790396065242, 2.0087322152666651, 2.9341741995890036, 3.6951049143237467, 4.7612118300914625]
# [0.71784090891847885, 1.0867395409006391, 2.0150109226300676, 3.1646766704252678, 4.5921199963255708]
# [1.4500457838467717, 2.9287777111163678, 3.8332457429495745, 4.2313225055264416, 5.0040750774549219]
# [0.86550104005318218, 1.2285162338261915, 2.017064489710835, 3.2018816676165396, 4.6207362183195118]
# [1.1641874035246653, 2.1817983520281738, 3.0374597387501376, 3.9381425590508643, 4.9717261203258722]
# [0.97826439071878057, 2.0147469061171179, 2.9785059464431058, 3.8690592138757913, 4.9021676375303835]
# [0.81882942798861658, 1.1569361956499775, 2.0076505812201391, 3.0293418886527359, 4.5030572049670674]
# [0.98852684234137445, 2.0287442599075476, 3.005366667540744, 3.950373962511414, 4.987075552264014]
# [0.98205517771509543, 2.1239892418292095, 3.1055712559189312, 3.9726825467328379, 4.9853575615362704]
# [1.4520427512185941, 2.869710850118441, 3.3669724082172245, 3.9745412908886872, 4.9800262262910122]
# [1.0182287162663728, 2.0296519730676068, 3.0107847312314377, 3.9561408347598208, 4.9885532314871455]
# [0.95726553792909252, 1.9573176072019765, 2.8791309528278721, 3.8986510060902511, 4.9769547971649928]
# [0.71701374043932775, 1.0835030821726095, 2.0039351896435158, 2.9978934310726104, 4.4924261685120035]
# [0.95776146540013873, 1.9518198720571165, 3.0425390245658721, 3.9608648002048623, 4.9887358263885435]
# [0.71933362073179208, 1.0865366670329373, 2.0152781312839001, 3.1951644512457662, 4.6140195705094822]
# [0.8236411924096636, 1.1686149367638476, 2.0197229527219589, 3.2177798257745227, 4.6352211497266351]
# [0.0, 0.99743685544221039, 2.014178658393015, 3.2002018160257251, 4.620554723286225]
# [0.97826439071878057, 2.0157665943823866, 3.0011149007725195, 3.9391338330337522, 4.9764967772466155]
# [0.99363741638711589, 2.0161253422160534, 2.9766274168358451, 3.8594308346658419, 4.906157280281028]
